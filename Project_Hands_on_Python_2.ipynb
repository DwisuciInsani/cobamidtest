# %%
pip install pandas
# Out:
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (1.5.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2023.3)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.10/dist-packages (from pandas) (1.23.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# #**Load data penumpang bus **

# %% [markdown]
# **Tahun 2017**

# %%
link_penump_bus_2017 = {
    'januari':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/e4b640be-d9a2-4ea0-b94f-b5313385c04c/download/Penumpang-Bus-Sekolah-Januari-2017.csv',
    'februari':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/37205a79-ddae-4ef1-a3ac-4df1fb343754/download/Penumpang-Bus-Sekolah-Februari-2017.csv',
    'maret':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/24f1c29f-539e-442a-9a63-c68fff3093da/download/Penumpang-Bus-Sekolah-Maret-2017.csv',
    'april':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/fb5b4760-2a36-47ef-b037-e99c23fd9461/download/Penumpang-Bus-Sekolah-April-2017.csv',
    'mei':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/f9236311-cdec-438d-9127-bf426a0b0b42/download/Penumpang-Bus-Sekolah-Mei-2017.csv',
    'juni':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/724e0d36-a683-40e2-aa5e-c4310e873b5d/download/Penumpang-Bus-Sekolah-Juni-2017.csv',
    'juli':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/6b325948-ddf6-4da1-a96f-268055859285/download/Penumpang-Bus-Sekolah-Juli-2017.csv',
    'agustus':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/04781028-0ffa-4ef7-9356-d52460e1f824/download/Penumpang-Bus-Sekolah-Agustus-2017.csv',
    'september':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/18a8356c-5263-4119-be05-652c28b8ea67/download/Penumpang-Bus-Sekolah-September-2017.csv',
    'oktober':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/7eb98893-67c6-403d-83cd-951d6dacf197/download/Penumpang-Bus-Sekolah-Oktober-2017.csv',
    'november':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/2a9e76b7-b044-4384-a329-5bc681bf8cf7/download/Penumpang-Bus-Sekolah-November-2017.csv',
    'desember':'https://data.jakarta.go.id/dataset/7cf2294c-b2d8-4960-9473-45b973ab4273/resource/29c3eced-52c0-408d-8b65-b6047ad29b22/download/Penumpang-Bus-Sekolah-Desember-2017.csv'

}

# %%
df_penump_bus_all_2017 = pd.DataFrame()

for bulan, link in link_penump_bus_2017.items():
  df_penump_bus_temp = pd.read_csv(link)
  df_penump_bus_temp['bulan'] = str(bulan)
  df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)

df_penump_bus_all_2017
# Out:
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-95-a636d5fdeb75>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2017 = df_penump_bus_all_2017.append(df_penump_bus_temp)
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 25      REGULER        RUTE 14                        BLOK. M - PONDOK LABU
# 26      REGULER        RUTE 15                          TEBET - PONDOK KOPI
# 27      REGULER        RUTE 16                    RUSUN MUARA BARU - GROGOL
# 28      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 29          NaN            NaN                                          NaN
#
#     jumlah_bus  jumlah_penumpang     bulan  Unnamed: 5  ritase
# 0        100.0           20358.0   januari         NaN     NaN
# 1         84.0           16302.0   januari         NaN     NaN
# 2         67.0           11416.0   januari         NaN     NaN
# 3        102.0           18655.0   januari         NaN     NaN
# 4         68.0           12332.0   januari         NaN     NaN
# ..         ...               ...       ...         ...     ...
# 25        52.0            7447.0  desember         NaN     NaN
# 26        53.0            7778.0  desember         NaN     NaN
# 27        38.0            8103.0  desember         NaN     NaN
# 28        40.0             105.0  desember         NaN     NaN
# 29         NaN               NaN  desember         NaN     NaN
#
# [369 rows x 8 columns]

# %%
df_penump_bus_all_2017.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 369 entries, 0 to 29
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type_operasi      366 non-null    object
#  1   daerah_operasi    366 non-null    object
#  2   area_operasi      366 non-null    object
#  3   jumlah_bus        365 non-null    float64
#  4   jumlah_penumpang  365 non-null    float64
#  5   bulan             369 non-null    object
#  6   Unnamed: 5        0 non-null      float64
#  7   ritase            29 non-null     float64
# dtypes: float64(4), object(4)
# memory usage: 25.9+ KB

# %%
print(df_penump_bus_all_2017.columns)
# Out:
# Index(['type_operasi', 'daerah_operasi', 'area_operasi', 'jumlah_bus',
#        'jumlah_penumpang', 'bulan', 'Unnamed: 5', 'ritase'],
#       dtype='object')

# %%
del(df_penump_bus_all_2017['Unnamed: 5'])
del(df_penump_bus_all_2017['ritase'])
df_penump_bus_all_2017
# Out:
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 25      REGULER        RUTE 14                        BLOK. M - PONDOK LABU
# 26      REGULER        RUTE 15                          TEBET - PONDOK KOPI
# 27      REGULER        RUTE 16                    RUSUN MUARA BARU - GROGOL
# 28      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 29          NaN            NaN                                          NaN
#
#     jumlah_bus  jumlah_penumpang     bulan
# 0        100.0           20358.0   januari
# 1         84.0           16302.0   januari
# 2         67.0           11416.0   januari
# 3        102.0           18655.0   januari
# 4         68.0           12332.0   januari
# ..         ...               ...       ...
# 25        52.0            7447.0  desember
# 26        53.0            7778.0  desember
# 27        38.0            8103.0  desember
# 28        40.0             105.0  desember
# 29         NaN               NaN  desember
#
# [369 rows x 6 columns]

# %%
newdf2017 = df_penump_bus_all_2017.dropna()
newdf2017
# Out:
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 24      REGULER        RUTE 13          PULO GADUNG -  PONDOK BAMBU -CAWANG
# 25      REGULER        RUTE 14                        BLOK. M - PONDOK LABU
# 26      REGULER        RUTE 15                          TEBET - PONDOK KOPI
# 27      REGULER        RUTE 16                    RUSUN MUARA BARU - GROGOL
# 28      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
#
#     jumlah_bus  jumlah_penumpang     bulan
# 0        100.0           20358.0   januari
# 1         84.0           16302.0   januari
# 2         67.0           11416.0   januari
# 3        102.0           18655.0   januari
# 4         68.0           12332.0   januari
# ..         ...               ...       ...
# 24        71.0            8958.0  desember
# 25        52.0            7447.0  desember
# 26        53.0            7778.0  desember
# 27        38.0            8103.0  desember
# 28        40.0             105.0  desember
#
# [365 rows x 6 columns]

# %%
#add kolom
newdf2017["tahun"] = "2017"
newdf2017
# Out:
# <ipython-input-177-e5c6469199e4>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2017["tahun"] = "2017"
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 24      REGULER        RUTE 13          PULO GADUNG -  PONDOK BAMBU -CAWANG
# 25      REGULER        RUTE 14                        BLOK. M - PONDOK LABU
# 26      REGULER        RUTE 15                          TEBET - PONDOK KOPI
# 27      REGULER        RUTE 16                    RUSUN MUARA BARU - GROGOL
# 28      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
#
#     jumlah_bus  jumlah_penumpang     bulan tahun
# 0        100.0           20358.0   januari  2017
# 1         84.0           16302.0   januari  2017
# 2         67.0           11416.0   januari  2017
# 3        102.0           18655.0   januari  2017
# 4         68.0           12332.0   januari  2017
# ..         ...               ...       ...   ...
# 24        71.0            8958.0  desember  2017
# 25        52.0            7447.0  desember  2017
# 26        53.0            7778.0  desember  2017
# 27        38.0            8103.0  desember  2017
# 28        40.0             105.0  desember  2017
#
# [365 rows x 7 columns]

# %%
#add id transaksi
#newdf2017['id'] = range(1, len(newdf2017) + 1)
#newdf2017
# Out:
# <ipython-input-58-5c2522999d14>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2017['id'] = range(1, len(newdf2017) + 1)
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 24      REGULER        RUTE 13          PULO GADUNG -  PONDOK BAMBU -CAWANG
# 25      REGULER        RUTE 14                        BLOK. M - PONDOK LABU
# 26      REGULER        RUTE 15                          TEBET - PONDOK KOPI
# 27      REGULER        RUTE 16                    RUSUN MUARA BARU - GROGOL
# 28      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
#
#     jumlah_bus  jumlah_penumpang     bulan tahun   id
# 0        100.0           20358.0   januari  2017    1
# 1         84.0           16302.0   januari  2017    2
# 2         67.0           11416.0   januari  2017    3
# 3        102.0           18655.0   januari  2017    4
# 4         68.0           12332.0   januari  2017    5
# ..         ...               ...       ...   ...  ...
# 24        71.0            8958.0  desember  2017  361
# 25        52.0            7447.0  desember  2017  362
# 26        53.0            7778.0  desember  2017  363
# 27        38.0            8103.0  desember  2017  364
# 28        40.0             105.0  desember  2017  365
#
# [365 rows x 8 columns]

# %% [markdown]
# **Tahun 2018**

# %%
link_penump_bus_2018 = {
    'januari':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/66adb89a-ae5d-462a-b0b4-3029ae108693/download/Data-Penumpang-Bus-Sekolah-Januari-2018.csv',
    'februari':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/f1ad67c2-1a66-4d48-bec4-03d67b3595b4/download/Data-Penumpang-Bus-Sekolah-Februari-2018.csv',
    'maret':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/9db1c6a8-ba55-4099-b325-6f9708dd93be/download/Data-Penumpang-Bus-Sekolah-Maret-2018.csv',
    'april':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/cfe8b2a1-ca56-4f54-9719-2fdef07b3f58/download/Data-Penumpang-Bus-Sekolah-April-2018.csv',
    'mei':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/2f6cfb75-0b15-4c58-8259-8258ba744931/download/Data-Penumpang-Bus-Sekolah-Mei-2018.csv',
    'juni':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/f8b54e46-dd99-4303-9604-00221a05e95d/download/Data-Penumpang-Bus-Sekolah-Juni-2018.csv',
    'juli':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/64b338e7-f40b-4aab-a2d7-0dcd305e4ce8/download/Data-Penumpang-Bus-Sekolah-Juli-2018.csv',
    'agustus':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/935859ce-a92b-4b3a-99fb-f517f4a7b89d/download/Data-Penumpang-Bus-Sekolah-Agustus-2018.csv',
    'september':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/7a281451-6b3a-492f-881c-daab0440b338/download/Data-Penumpang-Bus-Sekolah-September-2018.csv',
    'oktober':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/1871014a-94bb-4693-ace0-230f629d089d/download/Data-Penumpang-Bus-Sekolah-Oktober-2018.csv',
    'november':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/55a21757-3313-44d6-bafe-0721b86b5f99/download/Data-Penumpang-Bus-Sekolah-November-2018.csv',
    'desember':'https://data.jakarta.go.id/dataset/737d708e-0eea-4734-acdc-9038a38692ca/resource/12040d13-1079-4c4c-b1a8-73ce3f821d17/download/Data-Penumpang-Bus-Sekolah-Desember-2018.csv'

}

# %%
df_penump_bus_all_2018 = pd.DataFrame()

for bulan, link in link_penump_bus_2018.items():
  df_penump_bus_temp = pd.read_csv(link)
  df_penump_bus_temp['bulan'] = str(bulan)
  df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)

df_penump_bus_all_2018
# Out:
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
# <ipython-input-102-84be6c2c0a09>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2018 = df_penump_bus_all_2017.append(df_penump_bus_temp)
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus  jumlah_penumpang     bulan
# 0        100.0         20358.000   januari
# 1         84.0         16302.000   januari
# 2         67.0         11416.000   januari
# 3        102.0         18655.000   januari
# 4         68.0         12332.000   januari
# ..         ...               ...       ...
# 29        34.0             6.408  desember
# 30        26.0             3.505  desember
# 31        28.0             6.043  desember
# 32        30.0             3.130  desember
# 33        71.0             4.275  desember
#
# [403 rows x 6 columns]

# %%
df_penump_bus_all_2018.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 403 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type_operasi      400 non-null    object
#  1   daerah_operasi    400 non-null    object
#  2   area_operasi      400 non-null    object
#  3   jumlah_bus        399 non-null    float64
#  4   jumlah_penumpang  399 non-null    float64
#  5   bulan             403 non-null    object
# dtypes: float64(2), object(4)
# memory usage: 22.0+ KB

# %%
print(df_penump_bus_all_2017.columns)
# Out:
# Index(['type_operasi', 'daerah_operasi', 'area_operasi', 'jumlah_bus',
#        'jumlah_penumpang', 'bulan'],
#       dtype='object')

# %%
newdf2018 = df_penump_bus_all_2018.dropna()
newdf2018
# Out:
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus  jumlah_penumpang     bulan
# 0        100.0         20358.000   januari
# 1         84.0         16302.000   januari
# 2         67.0         11416.000   januari
# 3        102.0         18655.000   januari
# 4         68.0         12332.000   januari
# ..         ...               ...       ...
# 29        34.0             6.408  desember
# 30        26.0             3.505  desember
# 31        28.0             6.043  desember
# 32        30.0             3.130  desember
# 33        71.0             4.275  desember
#
# [399 rows x 6 columns]

# %%
#add kolom
newdf2018["tahun"] = "2018"
newdf2018
# Out:
# <ipython-input-178-65598dac5251>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2018["tahun"] = "2018"
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus  jumlah_penumpang     bulan tahun
# 0        100.0         20358.000   januari  2018
# 1         84.0         16302.000   januari  2018
# 2         67.0         11416.000   januari  2018
# 3        102.0         18655.000   januari  2018
# 4         68.0         12332.000   januari  2018
# ..         ...               ...       ...   ...
# 29        34.0             6.408  desember  2018
# 30        26.0             3.505  desember  2018
# 31        28.0             6.043  desember  2018
# 32        30.0             3.130  desember  2018
# 33        71.0             4.275  desember  2018
#
# [399 rows x 7 columns]

# %%
#add id transaksi
#newdf2018['id'] = range(1, len(newdf2018) + 1)
#newdf2018
# Out:
# <ipython-input-57-589343fc54ac>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   newdf2018['id'] = range(1, len(newdf2018) + 1)
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus  jumlah_penumpang     bulan tahun   id
# 0        100.0         20358.000   januari  2018    1
# 1         84.0         16302.000   januari  2018    2
# 2         67.0         11416.000   januari  2018    3
# 3        102.0         18655.000   januari  2018    4
# 4         68.0         12332.000   januari  2018    5
# ..         ...               ...       ...   ...  ...
# 29        34.0             6.408  desember  2018  395
# 30        26.0             3.505  desember  2018  396
# 31        28.0             6.043  desember  2018  397
# 32        30.0             3.130  desember  2018  398
# 33        71.0             4.275  desember  2018  399
#
# [399 rows x 8 columns]

# %% [markdown]
# **Tahun 2019**

# %%
link_penump_bus_2019 = {
    'januari':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/f268abb0-a698-48c7-89c0-98e89db6fde5/download/Data-Penumpang-Bus-Sekolah-Januari-2019.csv',
    'februari':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/2db6ec67-2217-4da1-a994-7bf770502997/download/Data-Penumpang-Bus-Sekolah-Februari-2019.csv',
    'maret':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/2e15072d-c4dd-4334-9b73-bbe09cd05d38/download/Data-Penumpang-Bus-Sekolah-Maret-2019.csv',
    'april':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/cadde2eb-61af-4e66-ad99-2d96daea2730/download/Data-Penumpang-Bus-Sekolah-April-2019.csv',
    'mei':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/d0f8993e-e422-4241-adec-b638ec673087/download/Data-Penumpang-Bus-Sekolah-Mei-2019.csv',
    'juni':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/dfdd18da-f011-419c-ba11-4cac7011f086/download/Data-Penumpang-Bus-Sekolah-Juni-2019.csv',
    'juli':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/17a1f125-3cdd-43f9-ade5-59265a8a629b/download/Data-Penumpang-Bus-Sekolah-Juli-2019.csv',
    'agustus':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/8b581cad-7b58-4761-b1fa-aa677a4323ef/download/Data-Penumpang-Bus-Sekolah-Agustus-2019.csv',
    'september':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/a7cf979a-520b-40e1-a2dc-ef131f350379/download/Data-Penumpang-Bus-Sekolah-September-2019.csv',
    'oktober':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/42444774-1bea-4e56-b626-d843f73580ea/download/Data-Penumpang-Bus-Sekolah-Oktober-2019.csv',
    'november':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/ab104258-0574-4b62-b4cc-63843d8b843d/download/Data-Penumpang-Bus-Sekolah-November-2019.csv',
    'desember':'https://data.jakarta.go.id/dataset/97ce3df4-c76c-41f5-a26f-6661fd760701/resource/6f307bfe-836d-4bd9-9f96-1f667925ab8c/download/Data-Penumpang-Bus-Sekolah-Desember-2019.csv'

}

# %%
df_penump_bus_all_2019 = pd.DataFrame()

for bulan, link in link_penump_bus_2018.items():
  df_penump_bus_temp = pd.read_csv(link)
  df_penump_bus_temp['bulan'] = str(bulan)
  df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)

df_penump_bus_all_2019
# Out:
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
# <ipython-input-108-6945ca4d8f9b>:6: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_penump_bus_all_2019 = df_penump_bus_all_2019.append(df_penump_bus_temp)
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus jumlah_penumpang     bulan
# 0          112           17.291   januari
# 1           86           11.228   januari
# 2           72            6.652   januari
# 3          105           14.405   januari
# 4           71            9.171   januari
# ..         ...              ...       ...
# 29          34            6.408  desember
# 30          26            3.505  desember
# 31          28            6.043  desember
# 32          30             3.13  desember
# 33          71            4.275  desember
#
# [368 rows x 6 columns]

# %%
df_penump_bus_all_2019.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 368 entries, 0 to 33
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type_operasi      368 non-null    object
#  1   daerah_operasi    368 non-null    object
#  2   area_operasi      368 non-null    object
#  3   jumlah_bus        368 non-null    int64
#  4   jumlah_penumpang  368 non-null    object
#  5   bulan             368 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 20.1+ KB

# %%
print(df_penump_bus_all_2019.columns)
# Out:
# Index(['type_operasi', 'daerah_operasi', 'area_operasi', 'jumlah_bus',
#        'jumlah_penumpang', 'bulan'],
#       dtype='object')

# %%
newdf2019 = df_penump_bus_all_2019.dropna()
newdf2019
# Out:
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus jumlah_penumpang     bulan
# 0          112           17.291   januari
# 1           86           11.228   januari
# 2           72            6.652   januari
# 3          105           14.405   januari
# 4           71            9.171   januari
# ..         ...              ...       ...
# 29          34            6.408  desember
# 30          26            3.505  desember
# 31          28            6.043  desember
# 32          30             3.13  desember
# 33          71            4.275  desember
#
# [368 rows x 6 columns]

# %%
#add kolom
newdf2019["tahun"] = "2019"
newdf2019
# Out:
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus jumlah_penumpang     bulan tahun
# 0          112           17.291   januari  2019
# 1           86           11.228   januari  2019
# 2           72            6.652   januari  2019
# 3          105           14.405   januari  2019
# 4           71            9.171   januari  2019
# ..         ...              ...       ...   ...
# 29          34            6.408  desember  2019
# 30          26            3.505  desember  2019
# 31          28            6.043  desember  2019
# 32          30             3.13  desember  2019
# 33          71            4.275  desember  2019
#
# [368 rows x 7 columns]

# %%
#add id transaksi
#newdf2019['id'] = range(1, len(newdf2019) + 1)
#newdf2019
# Out:
#    type_operasi daerah_operasi                                 area_operasi  \
# 0        ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1        ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2        ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3        ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4        ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ..          ...            ...                                          ...
# 29      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 30      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 31      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 32      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 33      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#     jumlah_bus jumlah_penumpang     bulan tahun   id
# 0          112           17.291   januari  2019    1
# 1           86           11.228   januari  2019    2
# 2           72            6.652   januari  2019    3
# 3          105           14.405   januari  2019    4
# 4           71            9.171   januari  2019    5
# ..         ...              ...       ...   ...  ...
# 29          34            6.408  desember  2019  364
# 30          26            3.505  desember  2019  365
# 31          28            6.043  desember  2019  366
# 32          30             3.13  desember  2019  367
# 33          71            4.275  desember  2019  368
#
# [368 rows x 8 columns]

# %% [markdown]
# **Menggabungkan Data menjadi satu dataset**

# %%
new_df = pd.merge(newdf2017, newdf2018, how='outer')
final_df = pd.merge(new_df, newdf2019, how='outer')
final_df
# Out:
# <ipython-input-180-0a620ba69495>:2: FutureWarning: In a future version, the Index constructor will not infer numeric dtypes when passed object-dtype sequences (matching Series behavior)
#   final_df = pd.merge(new_df, newdf2019, how='outer')
#      type_operasi daerah_operasi                                 area_operasi  \
# 0          ZONASI         ZONA 1  ZONASI PONDOK GEDE - HALIM- CONDET - RANCHO
# 1          ZONASI         ZONA 2                ZONASI KP.MELAYU - RAWAMANGUN
# 2          ZONASI         ZONA 3            ZONASI TERMINAL KALIDERES - KAMAL
# 3          ZONASI         ZONA 4        ZONASI KALIDERES -SEMANAN-DURIKOSAMBI
# 4          ZONASI         ZONA 5           ZONASI PULO GADUNG-MARDANI-PASEBAN
# ...           ...            ...                                          ...
# 1127      REGULER        RUTE 17                      MUARA BARU- MUARA ANGKE
# 1128      REGULER        RUTE 18                  UJI COBA (CILEDUG-MERURUYA)
# 1129      REGULER        RUTE 19    UJI COBA (BENDUNGAN HILLIR - KEMANGGISAN)
# 1130      REGULER        RUTE 20         UJI COBA ( KEMANGGISAN - DAAN MOGOT)
# 1131      REGULER        RUTE 21           PELAYANAN DILUAR JAM OPERASIOMNAL
#
#       jumlah_bus jumlah_penumpang     bulan tahun
# 0          100.0          20358.0   januari  2017
# 1           84.0          16302.0   januari  2017
# 2           67.0          11416.0   januari  2017
# 3          102.0          18655.0   januari  2017
# 4           68.0          12332.0   januari  2017
# ...          ...              ...       ...   ...
# 1127        34.0            6.408  desember  2019
# 1128        26.0            3.505  desember  2019
# 1129        28.0            6.043  desember  2019
# 1130        30.0             3.13  desember  2019
# 1131        71.0            4.275  desember  2019
#
# [1132 rows x 7 columns]

# %% [markdown]
# **Lakukan data manipulation pada *jumlah_bus dan jumlah_penumpang* supaya berada dalam satu format type.** Contoh:
# 89.96 => 8996
# 9000.0 => 9000
# 9000,0 => 9000

# %%
import math

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132 entries, 0 to 1131
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type_operasi      1132 non-null   object
#  1   daerah_operasi    1132 non-null   object
#  2   area_operasi      1132 non-null   object
#  3   jumlah_bus        1132 non-null   float64
#  4   jumlah_penumpang  1132 non-null   object
#  5   bulan             1132 non-null   object
#  6   tahun             1132 non-null   object
# dtypes: float64(1), object(6)
# memory usage: 70.8+ KB

# %%
final_df['jumlah_bus'] = final_df['jumlah_bus'].astype(dtype ='int64')
#final_df['jumlah_penumpang'] = final_df['jumlah_penumpang'].astype(dtype ='int64')
#final_df['jumlah_penumpang'] = final_df['jumlah_penumpang'].apply(lambda x: math.ceil(x))

# %%
final_df['jumlah_penumpang'] = final_df['jumlah_penumpang'].astype(str).replace(['[.,]', 'nan'], ["", 0], regex= True).astype(int)

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1132 entries, 0 to 1131
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   type_operasi      1132 non-null   object
#  1   daerah_operasi    1132 non-null   object
#  2   area_operasi      1132 non-null   object
#  3   jumlah_bus        1132 non-null   int64
#  4   jumlah_penumpang  1132 non-null   int64
#  5   bulan             1132 non-null   object
#  6   tahun             1132 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 70.8+ KB

# %% [markdown]
# **Lakukan aggregasi sum, mean, dan max dari jumlah_bus dan jumlah_penumpang berdasarkan tahun**

# %%
#Berdasarkan Tahun
#final_df.groupby('tahun').agg(
#    sum_jumlah_bus=('jumlah_bus', 'mean'),
#    mean_jumlah_bus=('jumlah_bus', 'sum'),
#    max_jumlah_bus=('jumlah_bus', 'max')
#    )
# Out:
#        sum_jumlah_bus  mean_jumlah_bus  max_jumlah_bus
# tahun
# 2017        68.676712            25067             175
# 2018        67.724311            27022             175
# 2019        68.937500            25369             183

# %%
final_df.groupby(['tahun'])['jumlah_bus','jumlah_penumpang'].sum()
# Out:
# <ipython-input-187-2e570e3deed2>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   final_df.groupby(['tahun'])['jumlah_bus','jumlah_penumpang'].sum()
#        jumlah_bus  jumlah_penumpang
# tahun
# 2017        25067          39726120
# 2018        27022          40003581
# 2019        25369           3901118

# %%
final_df.groupby(['tahun'])['jumlah_bus','jumlah_penumpang'].mean()
# Out:
# <ipython-input-188-bb7708ac7be8>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   final_df.groupby(['tahun'])['jumlah_bus','jumlah_penumpang'].mean()
#        jumlah_bus  jumlah_penumpang
# tahun
# 2017    68.676712     108838.684932
# 2018    67.724311     100259.601504
# 2019    68.937500      10600.864130

# %%
final_df.groupby(['tahun'])['jumlah_bus','jumlah_penumpang'].max()
# Out:
# <ipython-input-189-33560e5f6c82>:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   final_df.groupby(['tahun'])['jumlah_bus','jumlah_penumpang'].max()
#        jumlah_bus  jumlah_penumpang
# tahun
# 2017          175            423380
# 2018          175            423380
# 2019          183             45769

# %% [markdown]
# **Simpan Hasil Ke Dalam JSON**

# %%
export_df = final_df.groupby(['tahun']).sum()
export_df = final_df.groupby(['tahun']).mean()
export_df = final_df.groupby(['tahun']).max()
export_df.to_json('./task2_result.json', orient='records')
# Out:
# <ipython-input-200-efb5519209a8>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   export_df = final_df.groupby(['tahun']).sum()
# <ipython-input-200-efb5519209a8>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   export_df = final_df.groupby(['tahun']).mean()

# %%
export_df = final_df.groupby(['tahun'], as_index=False).sum()
export_df = final_df.groupby(['tahun'], as_index=False).mean()
export_df = final_df.groupby(['tahun'], as_index=False).max()
export_df.to_json('./task2_result.json', orient='records')
# Out:
# <ipython-input-201-7e3fdde8d7e1>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   export_df = final_df.groupby(['tahun'], as_index=False).sum()
# <ipython-input-201-7e3fdde8d7e1>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   export_df = final_df.groupby(['tahun'], as_index=False).mean()
